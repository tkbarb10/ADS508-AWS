# %% [markdown]
# # Amazon Rekognition

# %% [markdown]
# ## 1. The unsafe words detected in the default image

# %% [markdown]
# Detected unsafe word: damm
# Detected unsafe word: darn
# Detected unsafe word: crap

# %% [markdown]
# ## 2. The timestamps and confidence of the words AWS and Twitter in the video

# %% [markdown]
# Found flagged text at 18000 ms: AWS (Confidence: 98.18)
# Found flagged text at 18000 ms: Twitter (Confidence: 99.87)
# Found flagged text at 18000 ms: AWS (Confidence: 99.14)
# Found flagged text at 18000 ms: Twitter (Confidence: 99.86)

# %% [markdown]
# ## 3. After adding MONDAY to the unsafe word list, insert a screenshot of the cell titled Display list of detected unsafe text

# %% [markdown]
# <mark>***Display list of detected unsafe text***<mark>
#
# ![image.png](attachment:05586d01-595d-4b0e-8070-4b9b64107a1b.png)

# %% [markdown]
# ## 4. After adjusting the flagged text word list for the video text recognition in the cell titled Display Recognized Text in the Video, insert a screenshot of the cell Display Recognized Text in the Video

# %% [markdown]
# <mark>***Display Recognized Text in the Video***<mark>
#
# ![image.png](attachment:52aad8e2-19b5-4734-b909-0c171ec62a22.png)
